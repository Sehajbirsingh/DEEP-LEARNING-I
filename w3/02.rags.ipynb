MB 6.1 MB/s eta 0:00:01
#      ---------------------------------        11.7/13.8 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------       12.0/13.8 MB 6.1 MB/s eta 0:00:01
#      -----------------------------------      12.3/13.8 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------     12.5/13.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------    12.8/13.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------    13.1/13.8 MB 6.1 MB/s eta 0:00:01
#      --------------------------------------   13.4/13.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  13.7/13.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  13.8/13.8 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  13.8/13.8 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------- 13.8/13.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: sentence-transformers in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (0.3.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: filelock in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (0.27.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: Pillow in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: networkx in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: anyio in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Installing collected packages: pypdf, faiss-cpu
# Successfully installed faiss-cpu-1.9.0.post1 pypdf-5.1.0
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain_community in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.15 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (0.3.15)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (0.3.31)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (0.3.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain_community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain_community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain_community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain_huggingface in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_huggingface) (0.27.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_huggingface) (0.3.31)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_huggingface) (3.4.0)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_huggingface) (0.21.0)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain_huggingface) (4.48.1)
# Requirement already satisfied: filelock in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.3.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.10.6)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (9.0.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.1)
# Requirement already satisfied: scipy in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.14.1)
# Requirement already satisfied: Pillow in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (10.4.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (0.5.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.8.30)
# Requirement already satisfied: networkx in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain_huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: anyio in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mynam\downloads\deep learning i\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.3.1)
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

# Step 1: Load PDF as LangChain Documents
def load_pdf_as_documents(pdf_path):
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    return documents

# Step 2: Split Documents into Chunks
def split_documents_into_chunks(documents, chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    split_docs = text_splitter.split_documents(documents)
    return split_docs

# Step 3: Create FAISS Vector Store
def create_faiss_index_from_documents(documents):
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(documents, embeddings)
    return vector_store

# Step 4: Set Up HuggingFace Question Generation
def setup_qg_pipeline():
    model_name = "google/flan-t5-small"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# Step 5: RAG Pipeline Setup
def setup_rag_pipeline_with_documents(pdf_path):
    # Load PDF and split into chunks
    documents = load_pdf_as_documents(pdf_path)
    split_docs = split_documents_into_chunks(documents)

    # Create vector store
    vector_store = create_faiss_index_from_documents(split_docs)

    # Set up QA pipeline
    retriever = vector_store.as_retriever()
    qg_pipeline = setup_qg_pipeline()
    llm = HuggingFacePipeline(pipeline=qg_pipeline)
    qa_chain = RetrievalQA(llm=llm, retriever=retriever)

    return qa_chain

# %% [markdown]
# **Step 1** - Loading PDFs as LangChain Documents
# Explanation:
#
# This step uses PyPDFLoader to load a PDF and convert it into a list of Document objects.
# Each Document contains text and optional metadata, such as page numbers.

# %%
from langchain.document_loaders import PyPDFLoader

# Step 1: Load PDF as LangChain Documents
def load_pdf_as_documents(pdf_path):
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    return documents

# Example: Load a PDF
pdf_path = "example.pdf"  # Replace with your PDF file
documents = load_pdf_as_documents(pdf_path)

# Display the first few documents
print("Number of documents loaded:", len(documents))
print("First document content:", documents[0].page_content[:500])  # Print first 500 characters
# Out:
# Number of documents loaded: 61
# First document content: natural-resources.canada.ca /our-natural-resources/energy-sources-distribution/electricity-infrastru…
# Powering Canada’s Future: A Clean Electricity
# Strategy
# 155-197 minutes
# Table of Contents
# Foreword – Clean Electricity Strategy
# 1.0 The Case for Clean Electricity
# 1.1 Laying Out a Clean Electricity Strategy for Canada
# 1.2 A Strategy informed by extensive engagement, electricity sector experts,
# and Indigenous energy leaders
# 1.3 Key Guiding Principles
# 2.0 Toward the Grid of the Future
# 2.1 Global Co

# %% [markdown]
# **Step 2** - Splitting Documents into Chunks
# Explanation:
#
# Large documents need to be divided into smaller chunks to improve retrieval performance.
# RecursiveCharacterTextSplitter ensures that the text is split into manageable sizes while maintaining some overlap for context continuity.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Step 2: Split Documents into Chunks
def split_documents_into_chunks(documents, chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    split_docs = text_splitter.split_documents(documents)
    return split_docs

# Example: Split the loaded documents
chunked_documents = split_documents_into_chunks(documents)
print("Number of chunks created:", len(chunked_documents))
print("First chunk content:", chunked_documents[0].page_content[:500])  # Print first 500 characters
# Out:
# Number of chunks created: 198
# First chunk content: natural-resources.canada.ca /our-natural-resources/energy-sources-distribution/electricity-infrastru…
# Powering Canada’s Future: A Clean Electricity
# Strategy
# 155-197 minutes
# Table of Contents
# Foreword – Clean Electricity Strategy
# 1.0 The Case for Clean Electricity
# 1.1 Laying Out a Clean Electricity Strategy for Canada
# 1.2 A Strategy informed by extensive engagement, electricity sector experts,
# and Indigenous energy leaders
# 1.3 Key Guiding Principles
# 2.0 Toward the Grid of the Future
# 2.1 Global Co

# %% [markdown]
# **Step 3** - Creating a FAISS Vector Store
# Explanation:
#
# Text chunks are embedded into numerical vectors using sentence-transformers.
# FAISS (Facebook AI Similarity Search) is used to index these vectors for fast retrieval during queries.

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Step 3: Create FAISS Vector Store
def create_faiss_index_from_documents(documents):
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(documents, embeddings)
    vector_store.save_local("faiss_store")
    return vector_store

# Example: Create a FAISS index
vector_store = create_faiss_index_from_documents(chunked_documents)
print("FAISS vector store created!")
# Out:
# <ipython-input-15-6a6e5d2e830a>:6: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# FAISS vector store created!

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

# Step 4: Set Up HuggingFace Question Generation
def setup_qg_pipeline():
    model_name = "google/flan-t5-small"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return pipeline("text2text-generation", model=model, tokenizer=tokenizer)

def setup_rag_pipeline_with_documents(pdf_path):
    # Load and process documents
    documents = load_pdf_as_documents(pdf_path)
    split_docs = split_documents_into_chunks(documents)
    vector_store = create_faiss_index_from_documents(split_docs)

    # Set up retriever
    retriever = vector_store.as_retriever()

    # Set up HuggingFacePipeline
    qg_pipeline = setup_qg_pipeline()
    llm = HuggingFacePipeline(pipeline=qg_pipeline)

    # Define a prompt template for QA
    prompt_template = PromptTemplate(
        input_variables=["context", "question"],
        template="Given the context: {context}, answer the question: {question}",
    )

    # Create RetrievalQA chain
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",  # Default chain type for combining documents
        retriever=retriever,
        return_source_documents=True,  # To get the source of the answer
        chain_type_kwargs={"prompt": prompt_template},
    )

    # Return the qa_chain
    return qa_chain  # Added this return statement

# Example: Set up the RAG pipeline
pdf_path = "example.pdf"  # Replace with your PDF file
qa_chain = setup_rag_pipeline_with_documents(pdf_path)

# Query the pipeline
query = "What is the document about?"  # Modify this query as needed
response = qa_chain.invoke(query)

print("\n--- Query Response ---")
print(response)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Device set to use cpu
# Token indices sequence length is longer than the specified maximum sequence length for this model (601 > 512). Running this sequence through the model will result in indexing errors
# --- Query Response ---
# {'query': 'What is the document about?', 'result': 'The Kinship and Prosperity Report', 'source_documents': [Document(id='187c47b1-47aa-4808-83f9-5215649a6922', metadata={'source': 'example.pdf', 'page': 8, 'page_label': '9'}, page_content='advisory council, which first met in December 2022.\nThe Kinship and Prosperity Report focuses on six key themes: easing access to\nfunding; developing consistent project eligibility criteria that prioritize Indigenous\ncommunity benefits; advancing inclusive opportunities and a Just Transition;\naccelerating Indigenous leadership in the energy transition; respecting self-\ndetermination by prioritizing Indigenous-led decisions; and sustainably funding\nIndigenous participation.\n1.3 Key Guiding Principles\nSix key principles underpin the Clean Electricity Strategy and will guide federal\naction to support electricity grid decarbonization and expansion.\nPrinciple 1: Provincial and Territorial Jurisdiction Must be Respected and\nSupported with Policy Certainty\nProvinces and territories hold jurisdiction over electricity planning and operations\nwithin their borders, while the federal government regulates nuclear energy and'), Document(id='dec75792-b815-4cf0-8adc-877ce07212c2', metadata={'source': 'example.pdf', 'page': 32, 'page_label': '33'}, page_content='five years or less, which will apply to federally designated projects under the Impact\nAssessment Act, and the target of two years that will apply to non-designated\nproject permitting. A target of three years has been established for nuclear energy\nproject reviews. The Ministerial Working Group (MWG) Action Plan also calls on the\nGovernment of Canada to review existing laws and regulations that apply to federal\ndecision-making on projects. Following through on the Action Plan, the Impact\nAssessment Agency of Canada has also launched a new public-facing Dashboard\nthat will increase transparency and predictability on federal timelines for permitting\ndecisions. In addition to these measures, the Cabinet Directive outlines the need for\ncertainty and predictability where federal requirements, processes, timelines, and\ndecisions should be clearly communicated for proponents and investors in\nconsideration of commercial and construction implications and with a service-'), Document(id='f8f0bf7a-9d4e-48fc-84a5-c00b8d348b54', metadata={'source': 'example.pdf', 'page': 30, 'page_label': '31'}, page_content='faced in the North, the CER largely does not apply in Northern and remote\ncommunities that are not connected to the continental gridFootnote 48.\nBox 8. The Clean Electricity Regulations in Focus: Built on Engagement\nThe development of the CER was based on extensive engagement including\nseveral consultation rounds: a March 2022 Discussion paper, a July 2022 draft\nregulatory framework, August 2023: Draft Regulations in Canada Gazette, Part I,\nfollowed by a 75-day consultation period, February 2024: Public Update, outlining\nfeedback received and changes under consideration for the final regulations. Since\nthe publication of the draft CER in August 2023, the Department has held over 300\nmeetings and organized 7 webinars and considered over 850 unique comments and\n18,000 submissions from multiple letter writing campaigns. In response to feedback\nand supported by evidence, the CER include significant compliance flexibility for'), Document(id='d45bc867-fe51-49d7-98e2-3daadb9d553f', metadata={'source': 'example.pdf', 'page': 17, 'page_label': '18'}, page_content='the basic consultation and accommodation obligations found in the Constitution\nAct, 1982. This cannot be repeated, and all levels of government must ensure that the\nlegal duty to consult and accommodate is upheld on all new electricity projects. Today,\nIndigenous Peoples are increasingly leading and/or participating in the clean energy')]}
